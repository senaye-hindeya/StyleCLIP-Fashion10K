# %%
from src.train import train_clip, save_checkpoint

train_clip(
    model=model,
    train_loader=train_loader,
    optimizer=optimizer,
    device=device,
    epochs=3,
    start_epoch=start_epoch,
    checkpoint_path=checkpoint_path,
    save_checkpoint_fn=save_checkpoint
)
